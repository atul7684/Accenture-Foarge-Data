# %% [markdown]
# #connect to drive for loading the datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Install r3equired libreries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# #Load the 3 dataset

# %%
# reactionType data set
df = pd.read_csv("/content/drive/MyDrive/4.1.a ReactionTypes.csv")

# %%
# reaction dataset
df1 = pd.read_csv("/content/drive/MyDrive/4.1.b Reactions.csv")

# %%
# content dataset
df2 = pd.read_csv("/content/drive/MyDrive/4.1.c Content.csv")

# %% [markdown]
# # Convert the 3 dataset to dataframe and creating a copy of each dataset

# %%
reactionType = df.copy()
reaction = df1.copy()
content = df2.copy()

# %% [markdown]
# #Data Exploration

# %%
reactionType.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %% [markdown]
# #checking the data type and all info

# %%
reactionType.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     int64
#  1   Type        16 non-null     object
#  2   Sentiment   16 non-null     object
#  3   Score       16 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 640.0+ bytes

# %% [markdown]
# #checking the null values

# %%
reactionType.isnull().sum()
# Out:
# Unnamed: 0    0
# Type          0
# Sentiment     0
# Score         0
# dtype: int64

# %% [markdown]
# ---As we can see there is no null values in content dataframe ---

# %% [markdown]
# #checking the duplicated values

# %%
reactionType.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  -- As we can see there is no duplicated values in content dataframe---

# %% [markdown]
# #checking the unique value in content dataframe column wise

# %%
reactionType.nunique()
# Out:
# Unnamed: 0    16
# Type          16
# Sentiment      3
# Score         15
# dtype: int64

# %%
reactionType.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %% [markdown]
#  --  WE CAN SEE THE "UNNAMED: O" IS NOT REQUIRED FOR ANALYSIS.
#  SO WE CAN DROP THE COLUMN ---

# %%
#inplace= True will change the things permanently in the dataframe
reactionType.drop("Unnamed: 0",axis=1)#,inplace=True)
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
reactionType.head()
# we can see after droping the unnamwed: 0 column , still the column is appearing
#we can permanently drop column by giving inspace = True
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %% [markdown]
# #permanenty droping of unnamed: 0 column

# %%
reactionType.drop("Unnamed: 0",axis=1,inplace=True)

# %%
reactionType.head()
# Out:
#          Type Sentiment  Score
# 0       heart  positive     60
# 1        want  positive     70
# 2     disgust  negative      0
# 3        hate  negative      5
# 4  interested  positive     30

# %% [markdown]
# we can see there is no "unnamed : 0" colummn in reactionType dataframe

# %% [markdown]
# #we can move ahaed with reaction dataframe

# %%
reaction.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %% [markdown]
# we can see  here also 'unnamed:0' column is not required so we droping the column permanently

# %%
reaction.drop("Unnamed: 0",axis=1,inplace=True)

# %%
reaction.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2                                   NaN
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
#
#       Type             Datetime
# 0      NaN  2021-04-22 15:17:15
# 1  disgust  2020-11-07 09:43:50
# 2  dislike  2021-06-17 12:22:51
# 3   scared  2021-04-18 05:13:58
# 4  disgust  2021-01-06 19:13:01

# %% [markdown]
# We can see there is no "unnamed:0" column in reaction dataframe

# %% [markdown]
# #checking the null values

# %%
reaction.isnull().sum()
# Out:
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %% [markdown]
# #deleting the null values

# %%
reaction.dropna(inplace=True)

# %%
reaction.isnull().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# dtype: int64

# %%
reaction.head()
# Out:
#                              Content ID                               User ID  \
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4
#
#          Type             Datetime
# 1     disgust  2020-11-07 09:43:50
# 2     dislike  2021-06-17 12:22:51
# 3      scared  2021-04-18 05:13:58
# 4     disgust  2021-01-06 19:13:01
# 5  interested  2020-08-23 12:25:58

# %% [markdown]
# we succefully droped tyhe null records and there is no null values in the reaction datafframe

# %% [markdown]
# # we can move forwaerd with content dataframe

# %%
content.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
content['Content ID'].unique().shape
# Out:
# (1000,)

# %%
content.shape
# Out:
# (1000, 6)

# %% [markdown]
# we can see the 'unnamed: 0' and 'url' columns are not required  so we can drop these column

# %%
content.drop(["Unnamed: 0","URL"],axis=1,inplace=True)

# %%
content.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  beb1f34e-7870-46d6-9fc7-2e12eb83ce43
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  a5c65404-5894-4b87-82f2-d787cbee86b4
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  9fb4ce88-fac1-406c-8544-1a899cee7aaf
# 4  01ab84dd-6364-4236-abbb-3f237db77180  e206e31b-5f85-4964-b6ea-d7ee5324def1
#
#     Type        Category
# 0  photo        Studying
# 1  photo  healthy eating
# 2  photo  healthy eating
# 3  photo      technology
# 4  video            food

# %% [markdown]
# we can see the two column successfully droped from our content dataframe

# %%
reaction.head()
# Out:
#                              Content ID                               User ID  \
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4
#
#          Type             Datetime
# 1     disgust  2020-11-07 09:43:50
# 2     dislike  2021-06-17 12:22:51
# 3      scared  2021-04-18 05:13:58
# 4     disgust  2021-01-06 19:13:01
# 5  interested  2020-08-23 12:25:58

# %%
reactionType.head()
# Out:
#          Type Sentiment  Score
# 0       heart  positive     60
# 1        want  positive     70
# 2     disgust  negative      0
# 3        hate  negative      5
# 4  interested  positive     30

# %%
content.isnull().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Category      0
# dtype: int64

# %%
reaction.shape
# Out:
# (22534, 4)

# %%
print(reactionType.shape,
reaction.shape,
content.shape)
# Out:
# (16, 4) (22534, 4) (1000, 4)

# %%
reaction.head()
# Out:
#                              Content ID                               User ID  \
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4
#
#          Type             Datetime
# 1     disgust  2020-11-07 09:43:50
# 2     dislike  2021-06-17 12:22:51
# 3      scared  2021-04-18 05:13:58
# 4     disgust  2021-01-06 19:13:01
# 5  interested  2020-08-23 12:25:58

# %%
reaction["Type"].value_counts()
# Out:
# Type
# heart          1497
# peeking        1438
# scared         1436
# adore          1427
# interested     1425
# hate           1420
# love           1411
# disgust        1406
# dislike        1396
# want           1396
# super love     1393
# like           1391
# indifferent    1385
# cherish        1380
# worried        1379
# intrigued      1354
# Name: count, dtype: int64

# %%
sns.countplot(x="Type",data=reaction)#rotate the engle45degree
plt.xticks(rotation=45)
plt.show()

# %%
# top 5 reaction type
top_5_reaction_type = reaction["Type"].value_counts().head(5)
top_5_reaction_type
# Out:
# Type
# heart         1497
# peeking       1438
# scared        1436
# adore         1427
# interested    1425
# Name: count, dtype: int64

# %%
# checking the Sentiment and score with the value count of reaction_type
reactionType["Sentiment"].value_counts()
# Out:
# Sentiment
# positive    9
# negative    5
# neutral     2
# Name: count, dtype: int64

# %%
#groupby
reactionType.groupby(["Sentiment","Type"]).count()
# Out:
#                        Score
# Sentiment Type
# negative  disgust          1
#           dislike          1
#           hate             1
#           scared           1
#           worried          1
# neutral   indifferent      1
#           peeking          1
# positive  adore            1
#           cherish          1
#           heart            1
#           interested       1
#           intrigued        1
#           like             1
#           love             1
#           super love       1
#           want             1

# %%
reaction.columns
# Out:
# Index(['Content ID', 'User ID', 'Type', 'Datetime'], dtype='object')

# %%
reactionType.columns
# Out:
# Index(['Unnamed: 0', 'Type', 'Sentiment', 'Score'], dtype='object')

# %%
data = pd.merge(reaction,reactionType,on="Type")

# %%
data.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  13c06e7e-833d-47eb-a790-5e09ccfd8d2c
# 3  9f737e0a-3cdd-4d29-9d24-753f4e3be810  8b49caad-bcc5-43de-bf40-34a66ff8805c
# 4  230c4e4d-70c3-461d-b42c-ec09396efb3f  ef147ea5-9696-44d5-b6c2-a43f62fd8ce2
#
#       Type             Datetime Sentiment  Score
# 0  disgust  2020-11-07 09:43:50  negative      0
# 1  disgust  2021-01-06 19:13:01  negative      0
# 2  disgust  2021-04-09 02:46:20  negative      0
# 3  disgust  2021-03-28 21:15:26  negative      0
# 4  disgust  2020-08-04 05:40:33  negative      0

# %%
data.columns
# Out:
# Index(['Content ID', 'User ID', 'Type', 'Datetime', 'Sentiment', 'Score'], dtype='object')

# %%
data=data.drop(["Content ID","User ID"],axis=1)

# %%
#groupby
data.groupby(["Sentiment","Type"]).count()
# Out:
#                        Datetime  Score
# Sentiment Type
# negative  disgust          1406   1406
#           dislike          1396   1396
#           hate             1420   1420
#           scared           1436   1436
#           worried          1379   1379
# neutral   indifferent      1385   1385
#           peeking          1438   1438
# positive  adore            1427   1427
#           cherish          1380   1380
#           heart            1497   1497
#           interested       1425   1425
#           intrigued        1354   1354
#           like             1391   1391
#           love             1411   1411
#           super love       1393   1393
#           want             1396   1396

# %%
data["Score"].value_counts()
# Out:
# Score
# 70    2776
# 60    1497
# 35    1438
# 15    1436
# 72    1427
# 30    1425
# 5     1420
# 65    1411
# 0     1406
# 10    1396
# 75    1393
# 50    1391
# 20    1385
# 12    1379
# 45    1354
# Name: count, dtype: int64

# %%
data.groupby(["Score","Type"])["Score"].count()
# Out:
# Score  Type
# 0      disgust        1406
# 5      hate           1420
# 10     dislike        1396
# 12     worried        1379
# 15     scared         1436
# 20     indifferent    1385
# 30     interested     1425
# 35     peeking        1438
# 45     intrigued      1354
# 50     like           1391
# 60     heart          1497
# 65     love           1411
# 70     cherish        1380
#        want           1396
# 72     adore          1427
# 75     super love     1393
# Name: Score, dtype: int64

# %%
# find top 5  reaction_type depending upen value count
top_5_reactionType=data["Type"].value_counts().head(5)
top_5_reactionType
# Out:
# Type
# heart         1497
# peeking       1438
# scared        1436
# adore         1427
# interested    1425
# Name: count, dtype: int64

# %%
#visualize top 5  reaction_type , set unique colour to every type
plt.figure(figsize=(10,5))
sns.countplot(x="Type",data=data,order=top_5_reactionType.index,palette="Set2")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-51-82421be38c0e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Type",data=data,order=top_5_reactionType.index,palette="Set2")

# %%
top_5_reactionType
# Out:
# Type
# heart         1497
# peeking       1438
# scared        1436
# adore         1427
# interested    1425
# Name: count, dtype: int64

# %% [markdown]
# # find the records relavent to  top 5 reaction_type valuecounts  through  loc

# %%
df3= data.loc[data["Type"].isin(top_5_reactionType.index)]

# %%
df3
# Out:
#          Type             Datetime Sentiment  Score
# 2802   scared  2021-04-18 05:13:58  negative     15
# 2803   scared  2020-11-02 06:28:53  negative     15
# 2804   scared  2020-09-03 18:51:38  negative     15
# 2805   scared  2021-04-20 23:48:12  negative     15
# 2806   scared  2020-09-29 16:00:27  negative     15
# ...       ...                  ...       ...    ...
# 22529   adore  2020-10-04 22:26:33  positive     72
# 22530   adore  2020-09-18 10:50:50  positive     72
# 22531   adore  2020-10-31 03:58:44  positive     72
# 22532   adore  2020-06-25 15:12:29  positive     72
# 22533   adore  2020-12-17 16:32:57  positive     72
#
# [7223 rows x 4 columns]

# %% [markdown]
# # convert the dataframe to csv file

# %%
df3.to_csv("top_5_reaction_type.csv")

# %% [markdown]
# # download the csv file

# %%
# download the csv file
from google.colab import files
files.download("top_5_reaction_type.csv")

# %% [markdown]
# # find top 5  Category depending upen value count

# %%
# find top 5  Category depending upen value count
top_5_Category=content["Category"].value_counts().head(5)
top_5_Category
# Out:
# Category
# technology    71
# animals       67
# travel        67
# culture       63
# science       63
# Name: count, dtype: int64

# %% [markdown]
# # find the records relavent to  top 5 category valuecounts  through  loc
#
#
# ---

# %%
# find the records relavent to category valuecounts  through  loc
df2= content.loc[content["Category"].isin(top_5_Category.index)]

# %% [markdown]
# # convert the dataframe to csv file

# %%
# convert the dataframe to csv file
df2.to_csv("top_5_Category.csv")

# %% [markdown]
# # download the csv file

# %%
# download the csv file
from google.colab import files
files.download("top_5_Category.csv")

# %%
df2.shape
# Out:
# (331, 4)

# %%
content.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  beb1f34e-7870-46d6-9fc7-2e12eb83ce43
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  a5c65404-5894-4b87-82f2-d787cbee86b4
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  9fb4ce88-fac1-406c-8544-1a899cee7aaf
# 4  01ab84dd-6364-4236-abbb-3f237db77180  e206e31b-5f85-4964-b6ea-d7ee5324def1
#
#     Type        Category
# 0  photo        Studying
# 1  photo  healthy eating
# 2  photo  healthy eating
# 3  photo      technology
# 4  video            food

# %% [markdown]
# #find top 5 type of content

# %%
#find top 5 content Type depending upen value count
top_5_contentType=content['Type'].value_counts()
top_5_contentType
# Out:
# Type
# photo    261
# video    259
# GIF      244
# audio    236
# Name: count, dtype: int64

# %% [markdown]
# # find the records relavent to valuecounttop 5  content type  through  loc

# %%
df4= content.loc[content["Type"].isin(top_5_contentType.index)]
df4
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# ...

# %% [markdown]
# # convert the dataframe to csv file

# %%
df4.to_csv("top_5_contentType.csv")

# %% [markdown]
# # download the csv file

# %%
# download the csv file
from google.colab import files
files.download("top_5_contentType.csv")

# %%
new_content=content['Category'].value_counts()
new_content
# Out:
# Category
# technology           71
# animals              67
# travel               67
# culture              63
# science              63
# fitness              61
# food                 61
# healthy eating       61
# cooking              60
# soccer               58
# tennis               58
# education            57
# dogs                 56
# studying             55
# veganism             48
# public speaking      48
# Fitness               5
# Animals               4
# Science               4
# "soccer"              3
# "culture"             3
# Soccer                3
# "dogs"                2
# Education             2
# Studying              2
# Travel                2
# Food                  2
# "veganism"            1
# "public speaking"     1
# Public Speaking       1
# "technology"          1
# "cooking"             1
# Healthy Eating        1
# "studying"            1
# "food"                1
# Culture               1
# "tennis"              1
# Technology            1
# ...

# %%
new_content=content['Category'].value_counts().head(5)
new_content
# Out:
# Category
# technology    71
# animals       67
# travel        67
# culture       63
# science       63
# Name: count, dtype: int64

# %%
#visualize top_5_catagory, set unique  different colour to every catagory
plt.figure(figsize=(10,5))
sns.countplot(x="Category",data=content,order=new_content.index,palette="Set2")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-169-7481914479c9>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Category",data=content,order=new_content.index,palette="Set2")
